# %% [raw]
# ALGORITHM FOR PROJECT 3:
#
# START
#
# DECLARE a data structure (like a list or dictionary) to hold Girls' information.
#
# DECLARE a data structure to hold Boys' information.
#
# LOAD the library (Pandas) required to handle tabular data.
#
# CONVERT both sets of data into a DataFrame (a digital table).
#
# MERGE the Girls' table and the Boys' table into one single "Master Table."
#
# FORMAT the table columns to ensure they are aligned (Name, Age, Height, Score).
#
# DISPLAY the final table to the user.
#
# END

# %%
import pandas as pd
girls_data = {
    "Name": ['Evelyn', 'Jessica', 'Somto', 'Edith', 'Liza', 'Madonna', 'Waje', 'Tola', 'Aisha', 'Latifa'],
    'Age': [17, 16, 17, 18, 16, 18, 17, 20, 19, 17],
    'Height': [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5],
    'Score': [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]
}
boys_data = {
    'Name': ['Chinedu', 'Liam', 'Wale', 'Gbenga', 'Abiola', 'Kola', 'Kunle', 'George', 'Thomas', 'Wesley'],
    'Age': [19, 16, 18, 17, 20, 19, 16, 18, 17, 19],
    'Height': [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7],
    'Score': [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]
}
# STEP 3: Convert the raw dictionaries into Pandas DataFrames
df_girls = pd.DataFrame(girls_data)
df_boys = pd.DataFrame(boys_data)

# STEP 4: Add a 'Gender' column to distinguish the two groups in the final table
df_girls['Gender'] = 'Girl'
df_boys['Gender'] = 'Boy'

# STEP 5: Combine (Concatenate) both tables into one master table
# ignore_index=True ensures the row numbers go from 0 to 19 smoothly
final_table = pd.concat([df_girls, df_boys], ignore_index=True)

print("PROJECT 3: STUDENT DATA TABLE")
print(final_table)
# Out:
# PROJECT 3: STUDENT DATA TABLE
#        Name  Age  Height  Score Gender
# 0    Evelyn   17     5.5     80   Girl
# 1   Jessica   16     6.0     85   Girl
# 2     Somto   17     5.4     70   Girl
# 3     Edith   18     5.9     60   Girl
# 4      Liza   16     5.6     76   Girl
# 5   Madonna   18     5.5     66   Girl
# 6      Waje   17     6.1     87   Girl
# 7      Tola   20     6.0     95   Girl
# 8     Aisha   19     5.7     50   Girl
# 9    Latifa   17     5.5     49   Girl
# 10  Chinedu   19     5.7     74    Boy
# 11     Liam   16     5.9     87    Boy
# 12     Wale   18     5.8     75    Boy
# 13   Gbenga   17     6.1     68    Boy
# 14   Abiola   20     5.9     66    Boy
# 15     Kola   19     5.5     78    Boy
# 16    Kunle   16     6.1     87    Boy
# 17   George   18     5.4     98    Boy
# 18   Thomas   17     5.8     54    Boy
# 19   Wesley   19     5.7     60    Boy
